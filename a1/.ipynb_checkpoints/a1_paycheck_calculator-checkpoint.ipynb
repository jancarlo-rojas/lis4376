# %% [markdown]
# # Paycheck Calculator
#
# **Developer:** Jancarlo Rojas
# **Course:** LIS4376 – Artificial Intelligence Applications
#
# ## Program Requirements
# 1. Must use `float` data type for user input (except where noted).
# 2. Must round calculations to two decimal places.
# 3. Must format currency with a dollar sign and two decimal places.

# %%
# Get user input
hours = float(input("Enter hours worked: "))
hourly_rate = float(input("Enter hourly rate: $"))
tax_rate = float(input("Tax Rate (percent): "))
# Out:
# Enter hours worked:  4
# Enter hourly rate: $ 30
# Tax Rate (percent):  25

# %%
# Calculate
gross_pay = hours * hourly_rate
tax_amount = gross_pay * (tax_rate / 100)
net_pay = gross_pay - tax_amount

# %%
# Display results
print("\nProgram Output:")
print("Gross Pay:\t", "${0:,.2f}".format(gross_pay))
print("Tax Rate:\t", "{:.2f}%".format(tax_rate))
print("Tax Amount:\t", "${0:,.2f}".format(tax_amount))
print("Net Pay:\t", "${0:,.2f}".format(net_pay))
# Out:
# Program Output:
# Gross Pay:	 $120.00
# Tax Rate:	 2500.00%
# Tax Amount:	 $30.00
# Net Pay:	 $90.00
